# %% [markdown]
# ### **Import USGS Gage Data**

# %%
# Ensure to install dataretrieval package using 
# "conda install -c conda-forge dataretrieval"
import dataretrieval.nwis as nwis

import pandas as pd
import numpy as np
import random
import math

# %%
# specify the USGS site code for which we want data.
site = '03339000'


# get instantaneous values (iv)
df = nwis.get_record(sites=site, service='iv', start='2017-12-31', end='2018-01-01')
df.head(2)
# Out:
#                            00010 00010_cd   site_no  00060 00060_cd  00065  \
# datetime
# 2017-12-31 00:00:00-06:00    1.0        A  03339000  140.0        A   2.40
# 2017-12-31 00:15:00-06:00    1.0        A  03339000  138.0        A   2.39
#
#                           00065_cd  00095_ysi), [discontinued 10/5/21  \
# datetime
# 2017-12-31 00:00:00-06:00        A                              831.0
# 2017-12-31 00:15:00-06:00        A                              831.0
#
#                           00095_ysi), [discontinued 10/5/21_cd  \
# datetime
# 2017-12-31 00:00:00-06:00                                    A
# 2017-12-31 00:15:00-06:00                                    A
#
#                            00300_ysi), [discontinued 10/5/21  ...  \
# datetime                                                      ...
# 2017-12-31 00:00:00-06:00                               15.0  ...
# 2017-12-31 00:15:00-06:00                               15.0  ...
#
# ...

# %%
# # Load sites
# site_lists = ['03339000'] #['03339000', '06892000', '08080700']

# k=0
# for obs in zip(site_lists):
#     # get instantaneous values (iv)
#     df = nwis.get_record(sites=obs, service='iv', start='2017-12-31', end='2018-01-01')
#     print(df)
#     k+=1
